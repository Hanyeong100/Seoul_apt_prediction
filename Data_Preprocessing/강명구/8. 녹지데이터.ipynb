# %%
import geopandas as gpd

# %%
data = gpd.read_file('./Data/TN_GRNZN_W_SHP/TN_GRNZN_W.shp')

# %%
park = data

# %%
park
# Out:
#      GRNZN_ID       GLD_NAM     GLD_ADDR_K GRNZN_CL GLD_CTN_YE  GRNZN_AR  \
# 0           0      올림픽로 분리대           None    중앙분리대          0   28907.0
# 1           0  성내천둔치공원(오금동)           None    하천변조경          0   26390.0
# 2           0        풍납마을마당           None      휴게소          0    1192.0
# 3           0         신암중학교         암사동444     건물조경          0    1200.0
# 4           0        일원가로공원            일원동    가로녹지대          0   10771.0
# ...       ...           ...            ...      ...        ...       ...
# 2244        0       육사후문녹지대      공릉동223-24     광장녹지          0     680.0
# 2245        0       테헤란로분리대           None    분리녹지대          0    8253.0
# 2246        0        역촌마을마당  역촌1동2-108,9번지      휴게소          0     230.0
# 2247        0        잠원동녹지대      경부고속도로주흥교     광장녹지          0    3300.0
# 2248        0          반포로변     서빙고동 310번지    도로변녹지          0    3131.0
#
#       LDHC_QY GU_NM GU_CODE_SE CREAT_DE PO_FE_NM    SHAPE_AREA  SHAPE_LEN  \
# ...

# %%
cities = gpd.read_file('./Data/EMD_202302/emd.shp', encoding='euc-kr')

# %%
map = gpd.read_file('./Data/EMD_202302/emd.shp', encoding='euc-kr') # 전국 동 단위
map.crs={'init':'epsg:5179'}
# Out:
# c:\Users\mgkan\anaconda3\lib\site-packages\pyproj\crs\crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
cities = gpd.read_file('./Data/CTPRVN_202302/ctp_rvn.shp', encoding='euc-kr') # 전국 시 단위
cities.crs={'init':'epsg:5179'}
cities
# Out:
# c:\Users\mgkan\anaconda3\lib\site-packages\pyproj\crs\crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
#    CTPRVN_CD         CTP_ENG_NM CTP_KOR_NM  \
# 0         11              Seoul      서울특별시
# 1         26              Busan      부산광역시
# 2         27              Daegu      대구광역시
# 3         28            Incheon      인천광역시
# 4         29            Gwangju      광주광역시
# 5         30            Daejeon      대전광역시
# 6         31              Ulsan      울산광역시
# 7         36          Sejong-si    세종특별자치시
# 8         41        Gyeonggi-do        경기도
# 9         42         Gangwon-do        강원도
# 10        43  Chungcheongbuk-do       충청북도
# 11        44  Chungcheongnam-do       충청남도
# ...

# %%
iter = map.shape[0] # 동 사이즈로 시행
iter_list = [] # 결과

for i in range(iter):
    TF = map.geometry[i].within(cities.geometry[0])
    iter_list.append(TF)

Seoul = map.iloc[iter_list]
Seoul
# Out:
#        EMD_CD       EMD_ENG_NM EMD_KOR_NM  \
# 0    11110101    Cheongun-dong        청운동
# 1    11110102      Singyo-dong        신교동
# 2    11110103   Gungjeong-dong        궁정동
# 3    11110104       Hyoja-dong        효자동
# 4    11110105  Changseong-dong        창성동
# ..        ...              ...        ...
# 450  11710106     Samjeon-dong        삼전동
# 451  11710107       Garak-dong        가락동
# 452  11710108    Munjeong-dong        문정동
# 464  11740108    Seongnae-dong        성내동
# 465  11740109     Cheonho-dong        천호동
#
#                                               geometry
# 0    POLYGON ((953700.022 1954605.065, 953693.871 1...
# 1    POLYGON ((953233.465 1953996.984, 953235.183 1...
# 2    POLYGON ((953560.228 1954257.466, 953561.190 1...
# 3    POLYGON ((953519.843 1953890.785, 953518.489 1...
# 4    POLYGON ((953516.123 1953734.362, 953516.526 1...
# ..                                                 ...
# 450  POLYGON ((964365.139 1944699.482, 964355.678 1...
# ...

# %%
seoul_boundary = Seoul.geometry.boundary
seoul_boundary = seoul_boundary.to_crs('wgs1984')

# %%
seoul_boundary
# Out:
# 0      LINESTRING (126.97556 37.58968, 126.97549 37.5...
# 1      LINESTRING (126.97031 37.58418, 126.97033 37.5...
# 2      LINESTRING (126.97400 37.58654, 126.97401 37.5...
# 3      LINESTRING (126.97356 37.58323, 126.97355 37.5...
# 4      LINESTRING (126.97353 37.58182, 126.97354 37.5...
#                              ...
# 450    LINESTRING (127.09684 37.50087, 127.09674 37.4...
# 451    LINESTRING (127.13416 37.49844, 127.13678 37.4...
# 452    LINESTRING (127.13801 37.49437, 127.13807 37.4...
# 464    LINESTRING (127.13424 37.53556, 127.13423 37.5...
# 465    LINESTRING (127.14153 37.55080, 127.14154 37.5...
# Length: 408, dtype: geometry

# %%
import matplotlib.pyplot as plt

ax = seoul_boundary.plot(figsize=(16, 16))
park.plot(ax=ax, color='black')
plt.show()

# %%
Seoul = Seoul.to_crs('wgs1984')

# %%
Seoul.to_file('./Data/1차정제/서울시행정동geometry(EPSG4326).shp', encoding='euc-kr')

# %%
park.to_file('./Data/1차정제/서울시녹지대geometry(EPSG4326).shp', encoding='euc-kr')

# %%
park.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
import pandas as
