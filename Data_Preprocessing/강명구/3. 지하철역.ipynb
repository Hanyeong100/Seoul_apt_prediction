# %%
import pandas as pd

# %%
data = pd.read_csv('./Data/전체_도시철도역사정보_20230317.csv', encoding='euc-kr')

# %%
data
# Out:
#        역번호    역사명   노선번호          노선명                     영문역사명  한자역사명 환승역구분  \
# 0     0101     판암  S3001  대전 도시철도 1호선                     Panam     板岩   일반역
# 1     0102     신흥  S3001  대전 도시철도 1호선                  Sinheung     新興   일반역
# 2     0103     대동  S3001  대전 도시철도 1호선                  Dae-dong     大洞   일반역
# 3     0104     대전  S3001  대전 도시철도 1호선                   Daejeon     大田   일반역
# 4     0105    중앙로  S3001  대전 도시철도 1호선                 Jungangno    中央路   일반역
# ...    ...    ...    ...          ...                       ...    ...   ...
# 1045   115     공항  S2901   광주도시철도 1호선                   Airport     空港   일반역
# 1046   116   송정공원  S2901   광주도시철도 1호선            Songjeong Park   松汀公園   일반역
# 1047   117  광주송정역  S2901   광주도시철도 1호선  GwangjuSongjeong Station  光州松汀站   일반역
# 1048   118     도산  S2901   광주도시철도 1호선                     Dosan     道山   일반역
# 1049   119     평동  S2901   광주도시철도 1호선               Pyeong-dong     平洞   일반역
#
# ...

# %%
address = data['역사도로명주소']
address
# Out:
# 0            대전광역시 동구 옥천로 지하162 (판암동)
# 1            대전광역시 동구 옥천로 지하 70 (판암동)
# 2            대전광역시 동구 계족로 지하 176 (대동)
# 3            대전광역시 동구 중앙로 지하 218 (중동)
# 4           대전광역시 중구 중앙로 지하 145 (은행동)
#                     ...
# 1045    광주광역시 광산구 상무대로 지하 416-99(신촌동)
# 1046    광주광역시 광산구 상무대로 지하 314-99(송정동)
# 1047    광주광역시 광산구 상무대로 지하 201-99(송정동)
# 1048    광주광역시 광산구 상무대로 지하 125-99(도산동)
# 1049           광주광역시 광산구 평동로 870(월전동)
# Name: 역사도로명주소, Length: 1050, dtype: object

# %%
city = [i.split(' ')[0] for i in address]

# %%
data['위치도시'] = city

# %%
seoul_metro = data[(data['위치도시'] == '서울특별시') | (data['위치도시'] == '서울시')]
seoul_metro
# Out:
#       역번호       역사명   노선번호      노선명               영문역사명     한자역사명 환승역구분  \
# 331   A01        서울  I28A1  인천국제공항선               Seoul         -   환승역
# 332   A02        공덕  I28A1  인천국제공항선            Gongdeok        孔德   환승역
# 333   A03      홍대입구  I28A1  인천국제공항선        Hongik Univ.      弘大入口   환승역
# 334   A04  디지털미디어시티  I28A1  인천국제공항선  Digital Media City         -   환승역
# 335  A042      마곡나루  I28A1  인천국제공항선          Magongnaru      麻谷나루   환승역
# ..    ...       ...    ...      ...                 ...       ...   ...
# 931  1025       도곡역  I28K1      분당선               Dogok       道 谷   환승역
# 932  1026       구룡역  I28K1      분당선             Guryong       九 龍   일반역
# 933  1027      개포동역  I28K1      분당선          Gaepo-dong     開 浦 洞   일반역
# 934  1028    대모산입구역  I28K1      분당선            Daemosan  大 母 山入 口   일반역
# 935  1030       수서역  I28K1      분당선               Suseo       水 西   환승역
#
#                 환승노선번호                          환승노선명        역위도         역경도  \
# ...

# %%
sum(seoul_metro['역위도'].isna())
# Out:
# 299

# %%
seoul_metro[seoul_metro['역사명'] == '서울역']
# Out:
#       역번호  역사명   노선번호  노선명          영문역사명 한자역사명     환승역구분             환승노선번호  \
# 413  0133  서울역  I4101  1호선  Seoul Station     -  도시철도 환승역  I1104+I41K4+I28A1
# 515  0426  서울역  I1104  4호선  Seoul Station     -  도시철도 환승역  I4101+I41K4+I28A1
#
#                                          환승노선명  역위도  역경도   운영기관명  \
# 413  수도권  광역철도 4호선+수도권  광역철도 경의중앙+수도권  광역철도 공항  NaN  NaN  서울교통공사
# 515    수도권  광역철도 1호선+수도권 광역철도 경의중앙+수도권 광역철도 공항  NaN  NaN  서울교통공사
#
#                         역사도로명주소        역사전화번호     데이터기준일자   위치도시
# 413  서울특별시 중구 세종대로 지하2(남대문로 5가)  02-6110-1331  2022-05-01  서울특별시
# 515   서울특별시 용산구 한강대로 지하392(동자동)  02-6110-4261  2022-05-01  서울특별시

# %%
address = seoul_metro['역사도로명주소']
address
# Out:
# 331          서울특별시 용산구 청파로 378
# 332          서울특별시 마포구 마포대로 92
# 333          서울특별시 마포구 양화로 188
# 334          서울특별시 마포구 성암로 184
# 335     서울특별시 강서구 마곡중앙로 지하 135
#                 ...
# 931      서울시 강남구 남부순환로 지하 2814
# 932          서울시 강남구 개포동 175번지
# 933    서울시 강남구 개포동 지하 420(개포동)
# 934          서울시 강남구 일원동 611번지
# 935    서울시 강남구 광평로 지하 270(수서동)
# Name: 역사도로명주소, Length: 390, dtype: object

# %%
#구글맵 api 로드
import googlemaps
from datetime import datetime

my_key = "AIzaSyBviCKefFJeOxVJyhO-wXMMuH512NSomwo" #구글맵 API 키값
maps = googlemaps.Client(key=my_key)

import time #구동 시간을 측정하기 위하여 time 모듈 임포트


lat = []  #위도
lng = []  #경도

i=0

t1 = time.time() #지오코딩 코드 처리 전 시각

for add in address:   
    i = i + 1
    try:
        geo_location = maps.geocode(add)[0].get('geometry')
        lat.append(geo_location['location']['lat'])
        lng.append(geo_location['location']['lng'])
        
# 좌표를 가져오지 못한 경우 에러 출력
    except:
        lat.append('')
        lng.append('')
        print("%d번 인덱스 에러"%(i))


print(time.time() - t1) #지오코딩 총 구동 시간
# Out:
# 48.82968235015869

# %%
seoul_metro['위도'] = lat
seoul_metro['경도'] = lng
# Out:
# C:\Users\mgkan\AppData\Local\Temp/ipykernel_5400/2621786085.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seoul_metro['위도'] = lat
# C:\Users\mgkan\AppData\Local\Temp/ipykernel_5400/2621786085.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seoul_metro['경도'] = lng

# %%
seoul_metro.to_csv('./Data/서울시지하철역위치데이터.csv', encoding='euc-kr')
