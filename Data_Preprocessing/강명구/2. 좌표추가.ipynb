# %%
import pandas as pd

# %%
apt_trade = pd.read_csv("./Data/apt_trade.csv", encoding='utf-8')
# Out:
# c:\Users\mgkan\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (8,20,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
apt_trade
# Out:
#          Unnamed: 0  접수연도  자치구코드 자치구명  법정동코드   법정동명  지번구분 지번구분명      본번   부번  \
# 0                 2  2010  11650  서초구  10200    양재동   1.0    대지   154.0  2.0
# 1                 4  2010  11380  은평구  11400    진관동   1.0    대지    92.0  0.0
# 2                 6  2010  11710  송파구  11100    방이동   1.0    대지    89.0  0.0
# 3                 7  2010  11620  관악구  10100    봉천동   1.0    대지  1701.0  0.0
# 4                 8  2010  11710  송파구  10100    잠실동   1.0    대지    19.0  0.0
# ...             ...   ...    ...  ...    ...    ...   ...   ...     ...  ...
# 1007396      224458  2022  11170  용산구  12800  한강로3가   1.0    대지    98.0  0.0
# 1007397      224470  2022  11590  동작구  10700    사당동   1.0    대지    42.0  0.0
# 1007398      224475  2022  11710  송파구  11300    거여동   1.0    대지   234.0  0.0
# 1007399      224489  2022  11650  서초구  10800    서초동   1.0    대지  1315.0  0.0
# 1007400      224490  2022  11710  송파구  11300    거여동   1.0    대지   234.0  0.0
#
# ...

# %%
apt_trade['접수연도'].unique()
# Out:
# array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020,
#        2021, 2022], dtype=int64)

# %%
address_list = apt_trade['Address'].unique()
address_list
# Out:
# array(['서울특별시 서초구 양재동 우성아파트', '서울특별시 은평구 진관동 은평뉴타운 제각말 푸르지오(5-4단지)아파트',
#        '서울특별시 송파구 방이동 올림픽선수기자촌2단지아파트', ..., '서울특별시 중랑구 면목동 면목루브루아파트',
#        '서울특별시 양천구 목동 동도빌라트아파트', '서울특별시 송파구 마천동 한주리버뷰아파트'], dtype=object)

# %%
len(address_list)
# Out:
# 9819

# %%
#구글맵 api 로드
import googlemaps
from datetime import datetime

# %%
my_key = "AIzaSyBviCKefFJeOxVJyhO-wXMMuH512NSomwo" #구글맵 API 키값
maps = googlemaps.Client(key=my_key)

# %%
import time #구동 시간을 측정하기 위하여 time 모듈 임포트


lat = []  #위도
lng = []  #경도

i=0

t1 = time.time() #지오코딩 코드 처리 전 시각

for add in address_list:   
    i = i + 1
    try:
        geo_location = maps.geocode(add)[0].get('geometry')
        lat.append(geo_location['location']['lat'])
        lng.append(geo_location['location']['lng'])
        
# 좌표를 가져오지 못한 경우 에러 출력
    except:
        lat.append('')
        lng.append('')
        print("%d번 인덱스 에러"%(i))


print(time.time() - t1) #지오코딩 총 구동 시간
# Out:
# 16번 인덱스 에러
# 32번 인덱스 에러
# 61번 인덱스 에러
# 155번 인덱스 에러
# 159번 인덱스 에러
# 160번 인덱스 에러
# 161번 인덱스 에러
# 236번 인덱스 에러
# 298번 인덱스 에러
# 320번 인덱스 에러
# 322번 인덱스 에러
# 374번 인덱스 에러
# 419번 인덱스 에러
# 508번 인덱스 에러
# 554번 인덱스 에러
# 572번 인덱스 에러
# 696번 인덱스 에러
# 714번 인덱스 에러
# 724번 인덱스 에러
# 884번 인덱스 에러
# 931번 인덱스 에러
# 932번 인덱스 에러
# 953번 인덱스 에러
# 958번 인덱스 에러
# 970번 인덱스 에러
# 1066번 인덱스 에러
# 1076번 인덱스 에러
# 1084번 인덱스 에러
# 1132번 인덱스 에러
# 1201번 인덱스 에러
# 1281번 인덱스 에러
# 1294번 인덱스 에러
# 1299번 인덱스 에러
# 1302번 인덱스 에러
# 1360번 인덱스 에러
# 1463번 인덱스 에러
# 1477번 인덱스 에러
# 1483번 인덱스 에러
# 1576번 인덱스 에러
# 1613번 인덱스 에러
# 1694번 인덱스 에러
# 1736번 인덱스 에러
# 1746번 인덱스 에러
# 1848번 인덱스 에러
# 1958번 인덱스 에러
# 1990번 인덱스 에러
# 2055번 인덱스 에러
# 2137번 인덱스 에러
# 2232번 인덱스 에러
# 2370번 인덱스 에러
# 2410번 인덱스 에러
# 2507번 인덱스 에러
# 2513번 인덱스 에러
# 2516번 인덱스 에러
# 2559번 인덱스 에러
# 2573번 인덱스 에러
# 2621번 인덱스 에러
# 2627번 인덱스 에러
# 2630번 인덱스 에러
# 2697번 인덱스 에러
# 2723번 인덱스 에러
# 2732번 인덱스 에러
# 2743번 인덱스 에러
# 2756번 인덱스 에러
# 2775번 인덱스 에러
# 2914번 인덱스 에러
# 2972번 인덱스 에러
# 3052번 인덱스 에러
# ...

# %%
address = pd.DataFrame()
address
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
address = pd.read_csv('./Data/아파트좌표목록.csv', encoding='utf-8')
address
# Out:
#       Unnamed: 0                                 Address         위도  \
# 0              0                     서울특별시 서초구 양재동 우성아파트  37.474633
# 1              1  서울특별시 은평구 진관동 은평뉴타운 제각말 푸르지오(5-4단지)아파트  37.637820
# 2              2            서울특별시 송파구 방이동 올림픽선수기자촌2단지아파트  37.515283
# 3              3                    서울특별시 관악구 봉천동 건영6아파트  37.477073
# 4              4                   서울특별시 송파구 잠실동 잠실엘스아파트  37.513336
# ...          ...                                     ...        ...
# 9814        9814                  서울특별시 구로구 궁동 궁동에스하임아파트  37.500439
# 9815        9815              서울특별시 은평구 수색동 DMC아트포레자이아파트  37.584958
# 9816        9816                  서울특별시 중랑구 면목동 면목루브루아파트  37.588745
# 9817        9817                   서울특별시 양천구 목동 동도빌라트아파트  37.530204
# 9818        9818                  서울특별시 송파구 마천동 한주리버뷰아파트  37.498493
#
#               경도
# 0     127.032330
# 1     126.937431
# 2     127.134106
# 3     126.951891
# 4     127.080597
# ...          ...
# 9814  126.828530
# ...

# %%
apt_trade
# Out:
#          Unnamed: 0  접수연도  자치구코드 자치구명  법정동코드   법정동명  지번구분 지번구분명      본번   부번  \
# 0                 2  2010  11650  서초구  10200    양재동   1.0    대지   154.0  2.0
# 1                 4  2010  11380  은평구  11400    진관동   1.0    대지    92.0  0.0
# 2                 6  2010  11710  송파구  11100    방이동   1.0    대지    89.0  0.0
# 3                 7  2010  11620  관악구  10100    봉천동   1.0    대지  1701.0  0.0
# 4                 8  2010  11710  송파구  10100    잠실동   1.0    대지    19.0  0.0
# ...             ...   ...    ...  ...    ...    ...   ...   ...     ...  ...
# 1007396      224458  2022  11170  용산구  12800  한강로3가   1.0    대지    98.0  0.0
# 1007397      224470  2022  11590  동작구  10700    사당동   1.0    대지    42.0  0.0
# 1007398      224475  2022  11710  송파구  11300    거여동   1.0    대지   234.0  0.0
# 1007399      224489  2022  11650  서초구  10800    서초동   1.0    대지  1315.0  0.0
# 1007400      224490  2022  11710  송파구  11300    거여동   1.0    대지   234.0  0.0
#
# ...

# %%
merged_df = pd.merge(apt_trade, address, on='Address')
merged_df
# Out:
#          Unnamed: 0_x  접수연도  자치구코드 자치구명  법정동코드 법정동명  지번구분 지번구분명     본번   부번  \
# 0                   2  2010  11650  서초구  10200  양재동   1.0    대지  154.0  2.0
# 1                1459  2010  11650  서초구  10200  양재동   1.0    대지  154.0  2.0
# 2                1827  2010  11650  서초구  10200  양재동   1.0    대지  154.0  2.0
# 3                2528  2010  11650  서초구  10200  양재동   1.0    대지  154.0  2.0
# 4                8666  2010  11650  서초구  10200  양재동   1.0    대지  154.0  2.0
# ...               ...   ...    ...  ...    ...  ...   ...   ...    ...  ...
# 1007396        224117  2022  11710  송파구  11400  마천동   1.0    대지   22.0  1.0
# 1007397        224118  2022  11710  송파구  11400  마천동   1.0    대지   22.0  1.0
# 1007398        224119  2022  11710  송파구  11400  마천동   1.0    대지   22.0  1.0
# 1007399        224120  2022  11710  송파구  11400  마천동   1.0    대지   22.0  1.0
# 1007400        224121  2022  11710  송파구  11400  마천동   1.0    대지   22.0  1.0
#
# ...

# %%
merged_df.to_csv('./Data/apt_trade_좌표추가.csv', encoding='euc-kr')
