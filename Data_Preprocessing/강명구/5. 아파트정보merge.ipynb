# %%
import pandas as pd

# %%
apt_data = pd.read_csv('./Data/1차정제/apt_trade_좌표추가.csv', encoding='euc-kr')
# Out:
# c:\Users\mgkan\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
apt_info = pd.read_csv('./Data/서울시 공동주택 아파트 정보.csv', encoding='euc-kr')

# %%
apt_data
# Out:
#          Unnamed: 0  Unnamed: 0_x  접수연도  자치구코드 자치구명  법정동코드 법정동명  지번구분 지번구분명  \
# 0                 0             2  2010  11650  서초구  10200  양재동   1.0    대지
# 1                 1          1459  2010  11650  서초구  10200  양재동   1.0    대지
# 2                 2          1827  2010  11650  서초구  10200  양재동   1.0    대지
# 3                 3          2528  2010  11650  서초구  10200  양재동   1.0    대지
# 4                 4          8666  2010  11650  서초구  10200  양재동   1.0    대지
# ...             ...           ...   ...    ...  ...    ...  ...   ...   ...
# 1007396     1007396        224117  2022  11710  송파구  11400  마천동   1.0    대지
# 1007397     1007397        224118  2022  11710  송파구  11400  마천동   1.0    대지
# 1007398     1007398        224119  2022  11710  송파구  11400  마천동   1.0    대지
# 1007399     1007399        224120  2022  11710  송파구  11400  마천동   1.0    대지
# 1007400     1007400        224121  2022  11710  송파구  11400  마천동   1.0    대지
#
# ...

# %%
apt_trade_list = apt_data['건물명'].unique()

# %%
apt_info['건물명'] = apt_info['k-아파트명']

# %%
apt_info
# Out:
#          번호    k-아파트코드      k-아파트명 k-단지분류(아파트,주상복합등등)               kapt도로명주소  \
# 0         1  A15679103       우리유앤미                아파트        서울특별시 동작구 서달로 83
# 1         2  A13876112  송파파인타운13단지                아파트     서울특별시 송파구 송파대로8길 10
# 2         3  A13873701  오금현대백조(임대)                아파트    서울특별시 송파구 양재대로72길 20
# 3         4  A15275101        개봉건영                아파트  서울특별시 구로구 고척로21나길 85-6
# 4         6  A13991016    월계동원베네스트                아파트     서울특별시 노원구 월계로53길 21
# ...     ...        ...         ...                ...                     ...
# 2745  40319  A10023352  세운푸르지오헤리시티                아파트        서울특별시 중구 마른내로 79
# 2746  40320  A10023350        흑석자이                NaN        서울특별시 동작구 서달로 90
# 2747  40323  A10023348   개포자이프레지던스                NaN        서울특별시 강남구 삼성로 14
# 2748  40324  A10023336     자양하늘채베르                아파트        서울특별시 광진구 자양로 55
# 2749  40326  A10023322     삼전솔하임3차      도시형 생활주택(아파트)    서울특별시 성북구 동소문로46길 18
#
# ...

# %%
merged = pd.merge(apt_data, apt_info, on='건물명')
merged.head()
# Out:
#    Unnamed: 0  Unnamed: 0_x  접수연도  자치구코드 자치구명  법정동코드 법정동명  지번구분 지번구분명   본번  \
# 0        6166            23  2010  11650  서초구  10100  방배동   1.0    대지  754
# 1        6167           227  2010  11650  서초구  10100  방배동   1.0    대지  754
# 2        6168          3232  2010  11650  서초구  10100  방배동   1.0    대지  754
# 3        6169          3647  2010  11650  서초구  10100  방배동   1.0    대지  754
# 4        6170          3649  2010  11650  서초구  10100  방배동   1.0    대지  754
#
#    ...  청소비관리형태 건축면적   주차대수  기타/의무/임대/임의=1/2/3/4                  단지승인일  \
# 0  ...       위탁  0.0  779.0                   의무  2013-06-23 12:50:46.0
# 1  ...       위탁  0.0  779.0                   의무  2013-06-23 12:50:46.0
# 2  ...       위탁  0.0  779.0                   의무  2013-06-23 12:50:46.0
# 3  ...       위탁  0.0  779.0                   의무  2013-06-23 12:50:46.0
# 4  ...       위탁  0.0  779.0                   의무  2013-06-23 12:50:46.0
#
#    사용허가여부  관리비 업로드          좌표X        좌표Y                  단지신청일
# ...

# %%
len(merged['건물명'].unique())
# Out:
# 610
